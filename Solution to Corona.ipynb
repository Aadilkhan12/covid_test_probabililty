# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading Data

# %%
trainData = pd.read_csv("Train_dataset.csv")

# %%
trainData.head(10)
# Out:
#    people_ID        Region  Gender Designation             Name Married  \
# 0          1  Bhubaneshwar  Female         Mrs            mansi     YES
# 1          2  Bhubaneshwar  Female         Mrs        riya masi     YES
# 2          3  Bhubaneshwar  Female         Mrs           sunita      NO
# 3          4  Bhubaneshwar  Female         Mrs   anjali @ babli     YES
# 4          5  Bhubaneshwar  Female         Mrs  champa karketta      NO
# 5          6  Bhubaneshwar  Female         Mrs          sandhya     YES
# 6          7  Bhubaneshwar  Female         Mrs             iqra     YES
# 7          8  Bhubaneshwar  Female         Mrs     renu @ rinki     YES
# 8          9  Bhubaneshwar  Female         Mrs    kalyani patro     YES
# 9         10  Bhubaneshwar  Female         Mrs     gurdeep kaur     YES
#
#    Children     Occupation Mode_transport  cases/1M  ...    HBB d-dimer  \
# 0       1.0         Farmer         Public         2  ...   93.0   233.0
# ...

# %%
trainData.tail()
# Out:
#        people_ID     Region Gender Designation                 Name Married  \
# 10709      22691  Bengaluru   Male          Mr               ashish      NO
# 10710      22692  Bengaluru   Male          Mr  mohd mujahid ansari     YES
# 10711      22693  Bengaluru   Male          Mr           munnakumar     YES
# 10712      22694  Bengaluru   Male          Mr              prakash     YES
# 10713      22695  Bengaluru   Male          Mr      mehboob mehandi      NO
#
#        Children     Occupation Mode_transport  cases/1M  ...    HBB d-dimer  \
# 10709       2.0       Business            Car         8  ...   24.0   209.0
# 10710       0.0  Manufacturing            Car         8  ...  134.0   211.0
# 10711       0.0          Clerk         Public         8  ...  151.0   296.0
# 10712       1.0          Legal           Walk         8  ...  110.0   253.0
# 10713       2.0       Business            Car         8  ...  134.0   201.0
#
# ...

# %%
trainData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   people_ID               10714 non-null  int64
#  1   Region                  10714 non-null  object
#  2   Gender                  10714 non-null  object
#  3   Designation             10714 non-null  object
#  4   Name                    10694 non-null  object
#  5   Married                 10714 non-null  object
#  6   Children                10403 non-null  float64
#  7   Occupation              9967 non-null   object
#  8   Mode_transport          10711 non-null  object
#  9   cases/1M                10714 non-null  int64
#  10  Deaths/1M               10714 non-null  int64
#  11  comorbidity             10488 non-null  object
#  12  Age                     10714 non-null  int64
#  13  Coma score              10714 non-null  int64
# ...

# %%
trainData['Children'] = trainData['Children'].astype(np.float32)
trainData['Diuresis'] = trainData['Diuresis'].astype(np.float32)
trainData['Platelets'] = trainData['Platelets'].astype(np.float32)
trainData['HBB'] = trainData['HBB'].astype(np.float32)
trainData['d-dimer'] = trainData['d-dimer'].astype(np.float32)
trainData['Heart rate'] = trainData['Heart rate'].astype(np.float32)
trainData['HDL cholesterol'] = trainData['HDL cholesterol'].astype(np.float32)
trainData['Insurance'] = trainData['Insurance'].astype(np.float32)
trainData['FT/month'] = trainData['FT/month'].astype(np.float32)
trainData['Infect_Prob'] = trainData['Infect_Prob'].astype(np.float32)
trainData.describe()
# Out:
#           people_ID      Children      cases/1M     Deaths/1M           Age  \
# count  10714.000000  10403.000000  10714.000000  10714.000000  10714.000000
# mean   10084.893784      1.062770      3.285888      0.523241     42.083722
# std     7108.663645      0.818222      2.721274      0.854303     15.323397
# min        1.000000      0.000000      1.000000      0.000000     16.000000
# 25%     2679.250000      0.000000      2.000000      0.000000     29.000000
# 50%    10003.500000      1.000000      2.000000      0.000000     42.000000
# 75%    15141.750000      2.000000      4.000000      1.000000     55.000000
# max    22695.000000      2.000000      8.000000      2.000000     68.000000
#
#          Coma score     Diuresis    Platelets           HBB      d-dimer  \
# count  10714.000000  9998.000000  9790.000000  10698.000000  9600.000000
# mean       9.013067   278.806274    87.795815    116.170967   275.292297
# ...

# %%
testData = pd.read_csv("Test_dataset.csv")

# %%
testData
# Out:
#        people_ID              Region  Gender Designation  \
# 0           5942               Delhi  Female         Mrs
# 1          18664               Delhi    Male          Mr
# 2           5603               Delhi  Female         Mrs
# 3           5649               Delhi  Female         Mrs
# 4           5099               Delhi  Female         Mrs
# ...          ...                 ...     ...         ...
# 14493      23737  Thiruvananthapuram    Male          Mr
# 14494      11171  Thiruvananthapuram  Female         Mrs
# 14495      23243  Thiruvananthapuram    Male          Mr
# 14496      11199  Thiruvananthapuram  Female         Mrs
# 14497      10787  Thiruvananthapuram  Female         Mrs
#
#                           Name Married  Children Occupation Mode_transport  \
# 0           smt rekha prajapat     YES         2     Driver         Public
# 1                       nirmal     YES         2      Legal           Walk
# ...

# %%
trainData['Name'].fillna(trainData.Name.mode(), inplace=True)
trainData['Children'].fillna(2, inplace=True)
trainData['Occupation'].fillna(trainData.Occupation.mode(), inplace=True)
trainData['Mode_transport'].fillna(trainData.Mode_transport.mode(), inplace=True)
trainData['comorbidity'].fillna(trainData.comorbidity.mode(), inplace=True)
trainData['Children'].value_counts()
# Out:
# 2.0    4140
# 1.0    3398
# 0.0    3176
# Name: Children, dtype: int64

# %%
trainData['cardiological pressure'].value_counts()
# Out:
# Normal      2681
# Stage-01    2657
# Elevated    2641
# Stage-02    2638
# Name: cardiological pressure, dtype: int64

# %%
trainData['cardiological pressure'].fillna("Normal", inplace=True)
trainData['FT/month'].fillna(1.0, inplace=True)

# %%
trainData['cardiological pressure'].value_counts()
trainData['FT/month'] = trainData['FT/month'].astype(np.float32)
trainData['FT/month'].value_counts()
# Out:
# 1.0    4074
# 2.0    3343
# 0.0    3297
# Name: FT/month, dtype: int64

# %%
trainData['Diuresis'].fillna(trainData.Diuresis.mean(), inplace=True)
trainData['Platelets'].fillna(trainData.Platelets.mean(), inplace=True)
trainData['HBB'].fillna(trainData.HBB.mean(), inplace=True)
trainData['Insurance'].fillna(trainData.Insurance.mean(), inplace=True)

# %%
trainData['d-dimer'].fillna(275.292292, inplace=True)
trainData['Heart rate'].fillna(74.847392, inplace=True)
trainData['HDL cholesterol'].fillna(52.632737, inplace=True)

# %%
trainData['d-dimer'] = trainData['d-dimer'].astype(np.float32)
trainData['Heart rate'] = trainData['Heart rate'].astype(np.float32)
trainData['HDL cholesterol'] = trainData['HDL cholesterol'].astype(np.float32)

# %%
X_train = trainData[['people_ID','Children','cases/1M','Deaths/1M','Age','Coma score','Diuresis','Platelets','HBB','d-dimer','Heart rate','HDL cholesterol','Charlson Index','Blood Glucose','Insurance','salary','FT/month']].to_numpy()
X_test = testData[['people_ID','Children','cases/1M','Deaths/1M','Age','Coma score','Diuresis','Platelets','HBB','d-dimer','Heart rate','HDL cholesterol','Charlson Index','Blood Glucose','Insurance','salary','FT/month']].to_numpy()

Y_train = trainData[['Infect_Prob']].to_numpy().reshape(10714,)
trainData[['people_ID','Children','cases/1M','Deaths/1M','Age','Coma score','Diuresis','Platelets','HBB','d-dimer','Heart rate','HDL cholesterol','Charlson Index','Blood Glucose','Insurance','salary','FT/month']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   people_ID        10714 non-null  int64
#  1   Children         10714 non-null  float32
#  2   cases/1M         10714 non-null  int64
#  3   Deaths/1M        10714 non-null  int64
#  4   Age              10714 non-null  int64
#  5   Coma score       10714 non-null  int64
#  6   Diuresis         10714 non-null  float32
#  7   Platelets        10714 non-null  float32
#  8   HBB              10714 non-null  float32
#  9   d-dimer          10714 non-null  float32
#  10  Heart rate       10714 non-null  float32
#  11  HDL cholesterol  10714 non-null  float32
#  12  Charlson Index   10714 non-null  int64
#  13  Blood Glucose    10714 non-null  int64
#  14  Insurance        10714 non-null  float32
#  15  salary           10714 non-null  int64
# ...

# %%
one = 0
zero = 0
for i in range(10714):
    if Y_train[i]>=50:
        Y_train[i] = 1
    else:
        Y_train[i] = 0
Y_train
# Out:
# array([0., 1., 1., ..., 0., 1., 1.], dtype=float32)

# %%
testData['Infect_Prob'] = np.nan

# %%
testData['Infect_Prob'].fillna(0, inplace=True)

# %%
testData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14498 entries, 0 to 14497
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   people_ID               14498 non-null  int64
#  1   Region                  14498 non-null  object
#  2   Gender                  14498 non-null  object
#  3   Designation             14498 non-null  object
#  4   Name                    14466 non-null  object
#  5   Married                 14498 non-null  object
#  6   Children                14498 non-null  int64
#  7   Occupation              14498 non-null  object
#  8   Mode_transport          14498 non-null  object
#  9   cases/1M                14498 non-null  int64
#  10  Deaths/1M               14498 non-null  int64
#  11  comorbidity             14498 non-null  object
#  12  Age                     14498 non-null  int64
#  13  Coma score              14498 non-null  int64
# ...

# %%
Y_test = testData[['Infect_Prob']].to_numpy().reshape(14498,)

# %%
Y_test
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
input = [20696, 1, 2, 0, 68, 8, 441, 154, 93, 233, 82, 58, 27, 7, 3600000, 1300000, 2]
clf.predict_proba([input])
# Out:
# array([[0.53830505, 0.46169495]])
